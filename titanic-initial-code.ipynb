# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
trainOriginalData = pd.read_csv('/kaggle/input/titanic/train.csv')
testOriginalData = pd.read_csv('/kaggle/input/titanic/test.csv')
print(trainOriginalData.head(5))
print('\n')
print(testOriginalData.head(5))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
#
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
print(trainOriginalData.isna().sum(),"\n")
print(trainOriginalData.isna().sum())

# %%
trainData = trainOriginalData.drop(["Name","Sex","Ticket","Cabin","Embarked","Cabin"], axis = 1)
testData = testOriginalData.drop(["Name", "Sex", "Ticket", "Cabin","Embarked","Cabin"], axis = 1)

# %%
yTrain = trainData["Survived"]
xTrain = trainData.fillna(trainData.mode())
xTrain = xTrain.drop(["Survived"],axis = 1)
xTest = testData.fillna(trainData.mode())

# %%
print(xTrain.isna().sum(),"\n")
print(xTest.isna().sum())
xTrain['Fare'] = xTrain['Fare'].fillna(xTrain['Fare'].mean())
xTrain['Age'] = xTrain['Age'].fillna(xTrain['Age'].mean())
xTest['Age'] = xTest['Age'].fillna(xTest['Age'].mean())
xTest['Fare'] = xTest['Fare'].fillna(xTest['Fare'].mean())
print(xTest.isna().sum())
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64
#
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           1
# dtype: int64
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=100, min_samples_leaf= 3)
model.fit(xTrain, yTrain)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=3, random_state=100)

# %%
predictions = model.predict(xTest)

output = pd.DataFrame({'PassengerId': xTest.PassengerId, 'Survived': predictions})
output.to_csv('submissionBasicRF.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
from sklearn.neural_network import MLPClassifier

# %%
num_epochs = 30
num_hidden_units = 2048
learning_rate_init = 0.001
activation = 'relu'
SEED = 100

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(num_hidden_units,),
    activation=activation,
    learning_rate_init=learning_rate_init,
    warm_start=True,
    verbose=True,
    random_state=SEED,
    early_stopping=True,
    n_iter_no_change=100, # large number of iterations to avoid early stopping message
)

# %%
mlp.fit(xTrain, yTrain)
# Out:
# Iteration 1, loss = 5.92189652
# Validation score: 0.611111
# Iteration 2, loss = 2.08675965
# Validation score: 0.633333
# Iteration 3, loss = 3.13025659
# Validation score: 0.655556
# Iteration 4, loss = 1.62812045
# Validation score: 0.666667
# Iteration 5, loss = 1.00513699
# Validation score: 0.677778
# Iteration 6, loss = 0.80410819
# Validation score: 0.722222
# Iteration 7, loss = 0.67454088
# Validation score: 0.622222
# Iteration 8, loss = 1.10567252
# Validation score: 0.488889
# Iteration 9, loss = 1.08396207
# Validation score: 0.455556
# Iteration 10, loss = 1.17216287
# Validation score: 0.655556
# Iteration 11, loss = 0.88854680
# Validation score: 0.433333
# Iteration 12, loss = 1.34089198
# Validation score: 0.611111
# Iteration 13, loss = 1.57168966
# Validation score: 0.444444
# Iteration 14, loss = 1.35832649
# Validation score: 0.722222
# Iteration 15, loss = 0.83561055
# Validation score: 0.644444
# Iteration 16, loss = 1.20580955
# Validation score: 0.711111
# Iteration 17, loss = 0.81229606
# Validation score: 0.466667
# Iteration 18, loss = 1.01777233
# Validation score: 0.711111
# Validation score: 0.811111
# Iteration 176, loss = 0.59763292
# Validation score: 0.777778
# Iteration 177, loss = 0.54772699
# Validation score: 0.788889
# Iteration 178, loss = 0.51981347
# Validation score: 0.755556
# Iteration 179, loss = 0.73764120
# Validation score: 0.677778
# Iteration 180, loss = 0.71415621
# Validation score: 0.744444
# Iteration 181, loss = 0.68068901
# Validation score: 0.622222
# Iteration 182, loss = 0.74544078
# Validation score: 0.733333
# Iteration 183, loss = 0.69083369
# Validation score: 0.766667
# Iteration 184, loss = 1.05060274
# Validation score: 0.622222
# Iteration 185, loss = 2.64581171
# Validation score: 0.677778
# Iteration 186, loss = 1.13122902
# Validation score: 0.788889
# Iteration 187, loss = 0.68314253
# Validation score: 0.566667
# Iteration 188, loss = 1.11133150
# Validation score: 0.644444
# Iteration 189, loss = 1.79969089
# Validation score: 0.766667
# Iteration 190, loss = 1.33539965
# Validation score: 0.722222
# Iteration 191, loss = 1.37591234
# Validation score: 0.733333
# Iteration 192, loss = 0.66355176
# Validation score: 0.766667
# Iteration 193, loss = 0.56195075
# Validation score: 0.777778
# Iteration 194, loss = 0.51189664
# Validation score: 0.800000
# Iteration 195, loss = 0.51094567
# Validation score: 0.733333
# Iteration 196, loss = 1.16718592
# Validation score: 0.811111
# Iteration 197, loss = 0.68153176
# Validation score: 0.744444
# Iteration 198, loss = 0.81305810
# Validation score: 0.700000
# Iteration 199, loss = 0.64435825
# Validation score: 0.744444
# Iteration 200, loss = 0.76210352
# Validation score: 0.588889
# MLPClassifier(early_stopping=True, hidden_layer_sizes=(2048,),
#               n_iter_no_change=100, random_state=100, verbose=True,
#               warm_start=True)

# %%
predictions = mlp.predict(xTest)
output = pd.DataFrame({'PassengerId': xTest.PassengerId, 'Survived': predictions})
output.to_csv('submissionBasicCNN.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %% [markdown]
# ## Adding feature treatment

# %%
trainOriginalData = pd.read_csv('/kaggle/input/titanic/train.csv')
testOriginalData = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
trainOriginalData['Sex'] = pd.get_dummies(trainOriginalData['Sex'], dtype=int)["male"]
testOriginalData['Sex'] = pd.get_dummies(testOriginalData['Sex'], dtype=int)["male"]

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas    1  27.0      0
# 887                       Graham, Miss. Margaret Edith    0  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    0   NaN      1
# 889                              Behr, Mr. Karl Howell    1  26.0      0
# 890                                Dooley, Mr. Patrick    1  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
trainOriginalData["Age"] = trainOriginalData["Age"]/trainOriginalData["Age"].max()
trainOriginalData['Age'] = trainOriginalData['Age'].fillna(trainOriginalData['Age'].mean())

testOriginalData["Age"] = testOriginalData["Age"]/testOriginalData["Age"].max()
testOriginalData['Age'] = testOriginalData['Age'].fillna(testOriginalData['Age'].mean())

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  0.275000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.475000      1
# 2                               Heikkinen, Miss. Laina    0  0.325000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.437500      1
# 4                             Allen, Mr. William Henry    1  0.437500      0
# ..                                                 ...  ...       ...    ...
# 886                              Montvila, Rev. Juozas    1  0.337500      0
# 887                       Graham, Miss. Margaret Edith    0  0.237500      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  0.371239      1
# 889                              Behr, Mr. Karl Howell    1  0.325000      0
# 890                                Dooley, Mr. Patrick    1  0.400000      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
trainOriginalData = trainOriginalData.drop(["Ticket","Cabin","Name"], axis = 1)
testOriginalData = testOriginalData.drop(["Ticket","Cabin","Name"], axis = 1)

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  Sex       Age  SibSp  Parch     Fare  \
# 0              1         0       3    1  0.275000      1      0   7.2500
# 1              2         1       1    0  0.475000      1      0  71.2833
# 2              3         1       3    0  0.325000      0      0   7.9250
# 3              4         1       1    0  0.437500      1      0  53.1000
# 4              5         0       3    1  0.437500      0      0   8.0500
# ..           ...       ...     ...  ...       ...    ...    ...      ...
# 886          887         0       2    1  0.337500      0      0  13.0000
# 887          888         1       1    0  0.237500      0      0  30.0000
# 888          889         0       3    0  0.371239      1      2  23.4500
# 889          890         1       1    1  0.325000      0      0  30.0000
# 890          891         0       3    1  0.400000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
pd.get_dummies(trainOriginalData['Embarked'], dtype=int)
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
pd.concat([trainOriginalData, pd.get_dummies(trainOriginalData['Embarked'], dtype=int)], axis=1)
pd.concat([testOriginalData, pd.get_dummies(testOriginalData['Embarked'], dtype=int)], axis=1)
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare Embarked  C  \
# 0            892       3    1  0.453947      0      0    7.8292        Q  0
# 1            893       3    0  0.618421      1      0    7.0000        S  0
# 2            894       2    1  0.815789      0      0    9.6875        Q  0
# 3            895       3    1  0.355263      0      0    8.6625        S  0
# 4            896       3    0  0.289474      1      1   12.2875        S  0
# ..           ...     ...  ...       ...    ...    ...       ...      ... ..
# 413         1305       3    1  0.398324      0      0    8.0500        S  0
# 414         1306       1    0  0.513158      0      0  108.9000        C  1
# 415         1307       3    1  0.506579      0      0    7.2500        S  0
# 416         1308       3    1  0.398324      0      0    8.0500        S  0
# 417         1309       3    1  0.398324      1      1   22.3583        C  1
#
#      Q  S
# 0    1  0
# 1    0  1
# 2    1  0
# 3    0  1
# 4    0  1
# ..  .. ..
# 413  0  1
# 414  0  0
# 415  0  1
# 416  0  1
# 417  0  0
#
# [418 rows x 11 columns]

# %%
trainOriginalData = trainOriginalData.drop(["Embarked"], axis = 1)
testOriginalData = testOriginalData.drop(["Embarked"], axis = 1)

# %%
trainData = trainOriginalData
testData = testOriginalData

# %%
testData
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare
# 0            892       3    1  0.453947      0      0    7.8292
# 1            893       3    0  0.618421      1      0    7.0000
# 2            894       2    1  0.815789      0      0    9.6875
# 3            895       3    1  0.355263      0      0    8.6625
# 4            896       3    0  0.289474      1      1   12.2875
# ..           ...     ...  ...       ...    ...    ...       ...
# 413         1305       3    1  0.398324      0      0    8.0500
# 414         1306       1    0  0.513158      0      0  108.9000
# 415         1307       3    1  0.506579      0      0    7.2500
# 416         1308       3    1  0.398324      0      0    8.0500
# 417         1309       3    1  0.398324      1      1   22.3583
#
# [418 rows x 7 columns]
