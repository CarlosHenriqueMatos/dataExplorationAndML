# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
trainOriginalData = pd.read_csv('/kaggle/input/titanic/train.csv')
testOriginalData = pd.read_csv('/kaggle/input/titanic/test.csv')
print(trainOriginalData.head(5))
print('\n')
print(testOriginalData.head(5))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
#
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
print(trainOriginalData.isna().sum(),"\n")
print(trainOriginalData.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
trainData = trainOriginalData.drop(["Name","Sex","Ticket","Cabin","Embarked","Cabin"], axis = 1)
testData = testOriginalData.drop(["Name", "Sex", "Ticket", "Cabin","Embarked","Cabin"], axis = 1)

# %%
yTrain = trainData["Survived"]
xTrain = trainData.fillna(trainData.mode())
xTrain = xTrain.drop(["Survived"],axis = 1)
xTest = testData.fillna(trainData.mode())

# %%
print(xTrain.isna().sum(),"\n")
print(xTest.isna().sum())
xTrain['Fare'] = xTrain['Fare'].fillna(xTrain['Fare'].mean())
xTrain['Age'] = xTrain['Age'].fillna(xTrain['Age'].mean())
xTest['Age'] = xTest['Age'].fillna(xTest['Age'].mean())
xTest['Fare'] = xTest['Fare'].fillna(xTest['Fare'].mean())
print(xTest.isna().sum())
# Out:
# PassengerId      0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# dtype: int64
#
# PassengerId     0
# Pclass          0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# dtype: int64
# PassengerId    0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=100, min_samples_leaf= 3)
model.fit(xTrain, yTrain)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=3, random_state=100)

# %%
predictions = model.predict(xTest)

output = pd.DataFrame({'PassengerId': xTest.PassengerId, 'Survived': predictions})
output.to_csv('submissionBasicRF.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
from sklearn.neural_network import MLPClassifier

# %%
num_epochs = 30
num_hidden_units = 2048
learning_rate_init = 0.001
activation = 'relu'
SEED = 100

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(num_hidden_units,),
    activation=activation,
    learning_rate_init=learning_rate_init,
    warm_start=True,
    verbose=True,
    random_state=SEED,
    early_stopping=True,
    n_iter_no_change=100, # large number of iterations to avoid early stopping message
)

# %%
mlp.fit(xTrain, yTrain)
# Out:
# Iteration 1, loss = 5.81026709
# Validation score: 0.611111
# Iteration 2, loss = 6.04625752
# Validation score: 0.388889
# Iteration 3, loss = 12.85304809
# Validation score: 0.388889
# Iteration 4, loss = 10.34043498
# Validation score: 0.622222
# Iteration 5, loss = 6.47621935
# Validation score: 0.600000
# Iteration 6, loss = 7.01355940
# Validation score: 0.566667
# Iteration 7, loss = 2.43751102
# Validation score: 0.422222
# Iteration 8, loss = 1.94751022
# Validation score: 0.555556
# Iteration 9, loss = 1.79168513
# Validation score: 0.566667
# Iteration 10, loss = 3.25066793
# Validation score: 0.566667
# Iteration 11, loss = 3.43532653
# Validation score: 0.377778
# Iteration 12, loss = 2.94885073
# Validation score: 0.600000
# Iteration 13, loss = 1.58540200
# Validation score: 0.433333
# Iteration 14, loss = 1.40266231
# Validation score: 0.577778
# Iteration 15, loss = 2.37525988
# Validation score: 0.588889
# Iteration 16, loss = 3.51408648
# Validation score: 0.588889
# Iteration 17, loss = 2.84054533
# Validation score: 0.433333
# Iteration 18, loss = 2.90830246
# Validation score: 0.577778
# Iteration 19, loss = 1.44910797
# Validation score: 0.600000
# Iteration 20, loss = 2.47933757
# Validation score: 0.611111
# Iteration 21, loss = 3.04037206
# Validation score: 0.400000
# Iteration 22, loss = 2.70987835
# Validation score: 0.555556
# Iteration 23, loss = 3.03953437
# Validation score: 0.566667
# Iteration 24, loss = 1.81916613
# Validation score: 0.411111
# Iteration 25, loss = 1.84947805
# Validation score: 0.588889
# Iteration 26, loss = 1.28632214
# Validation score: 0.611111
# Iteration 27, loss = 1.58297442
# Validation score: 0.577778
# Iteration 28, loss = 2.98330190
# Validation score: 0.544444
# Iteration 29, loss = 1.96250602
# Validation score: 0.555556
# Iteration 30, loss = 2.16041793
# Validation score: 0.488889
# Iteration 31, loss = 1.56661697
# Validation score: 0.600000
# Iteration 32, loss = 1.97586886
# Validation score: 0.533333
# Iteration 33, loss = 1.09572844
# Validation score: 0.577778
# Iteration 34, loss = 1.06979664
# Validation score: 0.611111
# Iteration 35, loss = 0.88486764
# Validation score: 0.466667
# Iteration 36, loss = 1.21577891
# Validation score: 0.577778
# Iteration 37, loss = 1.24589409
# Validation score: 0.422222
# Iteration 38, loss = 1.53702356
# Validation score: 0.577778
# Iteration 39, loss = 1.90788339
# Validation score: 0.400000
# Iteration 40, loss = 8.25061001
# Validation score: 0.400000
# Iteration 41, loss = 3.83332056
# Validation score: 0.611111
# Iteration 42, loss = 2.51243335
# Validation score: 0.411111
# Iteration 43, loss = 2.90121734
# Validation score: 0.600000
# Iteration 44, loss = 2.59424064
# Validation score: 0.600000
# Iteration 45, loss = 1.70187327
# Validation score: 0.544444
# Iteration 46, loss = 2.37840081
# Validation score: 0.566667
# Iteration 47, loss = 3.50945538
# Validation score: 0.500000
# Iteration 48, loss = 1.93787785
# Validation score: 0.388889
# Iteration 49, loss = 4.14427330
# Validation score: 0.644444
# Iteration 50, loss = 3.14547634
# Validation score: 0.600000
# Iteration 51, loss = 2.46763434
# Validation score: 0.466667
# Iteration 52, loss = 2.64413889
# Validation score: 0.633333
# Iteration 53, loss = 2.61154697
# Validation score: 0.577778
# Iteration 54, loss = 1.69759617
# Validation score: 0.455556
# Iteration 55, loss = 1.47685805
# Validation score: 0.577778
# Iteration 56, loss = 1.91596396
# Validation score: 0.577778
# Iteration 57, loss = 1.04313330
# Validation score: 0.577778
# Iteration 58, loss = 0.94157934
# Validation score: 0.566667
# Iteration 59, loss = 0.94058807
# Validation score: 0.622222
# Iteration 60, loss = 0.97782263
# Validation score: 0.488889
# Iteration 61, loss = 1.36827479
# Validation score: 0.566667
# Iteration 62, loss = 1.64374902
# Validation score: 0.555556
# Iteration 63, loss = 1.03858360
# Validation score: 0.577778
# Iteration 64, loss = 1.13605747
# Validation score: 0.588889
# Iteration 65, loss = 0.75703621
# Validation score: 0.466667
# Iteration 66, loss = 1.22958947
# Validation score: 0.566667
# Iteration 67, loss = 1.06449017
# Validation score: 0.488889
# Iteration 68, loss = 0.89921599
# Validation score: 0.555556
# Iteration 69, loss = 0.89749619
# Validation score: 0.588889
# Iteration 70, loss = 0.89510492
# Validation score: 0.600000
# Iteration 71, loss = 0.73067591
# Validation score: 0.555556
# Iteration 72, loss = 0.63372341
# Validation score: 0.622222
# Iteration 73, loss = 0.68807050
# Validation score: 0.555556
# Iteration 74, loss = 0.68023569
# Validation score: 0.555556
# Iteration 75, loss = 0.95315813
# Validation score: 0.622222
# Iteration 76, loss = 1.41040310
# Validation score: 0.600000
# Iteration 77, loss = 0.83250175
# Validation score: 0.600000
# Iteration 78, loss = 0.88565547
# Validation score: 0.455556
# Iteration 79, loss = 1.11665928
# Validation score: 0.644444
# Iteration 80, loss = 0.97771234
# Validation score: 0.600000
# Iteration 81, loss = 0.91739266
# Validation score: 0.611111
# Iteration 82, loss = 3.17589329
# Validation score: 0.622222
# Iteration 83, loss = 2.52596391
# Validation score: 0.577778
# Iteration 84, loss = 3.38198904
# Validation score: 0.655556
# Iteration 85, loss = 0.97721396
# Validation score: 0.600000
# Iteration 86, loss = 1.13584181
# Validation score: 0.577778
# Iteration 87, loss = 0.96194490
# Validation score: 0.611111
# Iteration 88, loss = 0.95233373
# Validation score: 0.488889
# Iteration 89, loss = 1.10993722
# Validation score: 0.655556
# Iteration 90, loss = 0.80844602
# Validation score: 0.600000
# Iteration 91, loss = 2.09465220
# Validation score: 0.566667
# Iteration 92, loss = 1.11035553
# Validation score: 0.566667
# Iteration 93, loss = 2.46974700
# Validation score: 0.566667
# Iteration 94, loss = 1.57748875
# Validation score: 0.555556
# Iteration 95, loss = 0.87607089
# Validation score: 0.511111
# Iteration 96, loss = 0.98580272
# Validation score: 0.544444
# Iteration 97, loss = 1.04507055
# Validation score: 0.400000
# Iteration 98, loss = 1.35080181
# Validation score: 0.611111
# Iteration 99, loss = 1.35275983
# Validation score: 0.388889
# Iteration 100, loss = 3.72080367
# Validation score: 0.611111
# Iteration 101, loss = 3.67813262
# Validation score: 0.622222
# Iteration 102, loss = 1.69033828
# Validation score: 0.455556
# Iteration 103, loss = 1.50455619
# Validation score: 0.600000
# Iteration 104, loss = 1.56161170
# Validation score: 0.544444
# Iteration 105, loss = 1.08405747
# Validation score: 0.588889
# Iteration 106, loss = 1.14800510
# Validation score: 0.611111
# Iteration 107, loss = 1.31263093
# Validation score: 0.488889
# Iteration 108, loss = 1.01672623
# Validation score: 0.555556
# Iteration 109, loss = 1.29570873
# Validation score: 0.411111
# Iteration 110, loss = 1.47429207
# Validation score: 0.588889
# Iteration 111, loss = 2.45461552
# Validation score: 0.511111
# Iteration 112, loss = 1.21653747
# Validation score: 0.600000
# Iteration 113, loss = 1.57538385
# Validation score: 0.577778
# Iteration 114, loss = 0.97252665
# Validation score: 0.611111
# Iteration 115, loss = 0.98172078
# Validation score: 0.588889
# Iteration 116, loss = 0.84049595
# Validation score: 0.600000
# Iteration 117, loss = 0.76171974
# Validation score: 0.555556
# Iteration 118, loss = 2.00184644
# Validation score: 0.611111
# Iteration 119, loss = 1.12753380
# Validation score: 0.633333
# Iteration 120, loss = 1.09586375
# Validation score: 0.555556
# Iteration 121, loss = 0.77158757
# Validation score: 0.588889
# Iteration 122, loss = 0.88612219
# Validation score: 0.588889
# Iteration 123, loss = 0.75756278
# Validation score: 0.622222
# Iteration 124, loss = 0.84442678
# Validation score: 0.477778
# Iteration 125, loss = 0.91071835
# Validation score: 0.566667
# Iteration 126, loss = 0.92972875
# Validation score: 0.444444
# Iteration 127, loss = 0.96451809
# Validation score: 0.555556
# Iteration 128, loss = 0.99147963
# Validation score: 0.422222
# Iteration 129, loss = 1.14771190
# Validation score: 0.577778
# Iteration 130, loss = 0.98786957
# Validation score: 0.411111
# Iteration 131, loss = 1.11757611
# Validation score: 0.566667
# Iteration 132, loss = 1.12425122
# Validation score: 0.611111
# Iteration 133, loss = 0.96995794
# Validation score: 0.644444
# Iteration 134, loss = 0.79183685
# Validation score: 0.644444
# Iteration 135, loss = 0.84985469
# Validation score: 0.488889
# Iteration 136, loss = 1.19798552
# Validation score: 0.666667
# Iteration 137, loss = 0.94434509
# Validation score: 0.577778
# Iteration 138, loss = 0.97293947
# Validation score: 0.466667
# Iteration 139, loss = 0.95540642
# Validation score: 0.566667
# Iteration 140, loss = 0.94596315
# Validation score: 0.566667
# Iteration 141, loss = 3.59377570
# Validation score: 0.577778
# Iteration 142, loss = 2.22312192
# Validation score: 0.488889
# Iteration 143, loss = 1.47563614
# Validation score: 0.555556
# Iteration 144, loss = 1.33455870
# Validation score: 0.533333
# Iteration 145, loss = 1.03243444
# Validation score: 0.488889
# Iteration 146, loss = 0.94419061
# Validation score: 0.555556
# Iteration 147, loss = 0.97238639
# Validation score: 0.566667
# Iteration 148, loss = 0.74027276
# Validation score: 0.633333
# Iteration 149, loss = 0.77831123
# Validation score: 0.588889
# Iteration 150, loss = 4.22321148
# Validation score: 0.577778
# Iteration 151, loss = 3.25023743
# Validation score: 0.400000
# Iteration 152, loss = 1.94954062
# Validation score: 0.566667
# Iteration 153, loss = 2.36813914
# Validation score: 0.566667
# Iteration 154, loss = 3.79373229
# Validation score: 0.522222
# Iteration 155, loss = 1.49267631
# Validation score: 0.577778
# Iteration 156, loss = 1.38462159
# Validation score: 0.444444
# Iteration 157, loss = 1.59927620
# Validation score: 0.600000
# Iteration 158, loss = 1.48855698
# Validation score: 0.466667
# Iteration 159, loss = 0.89360250
# Validation score: 0.611111
# Iteration 160, loss = 0.86847812
# Validation score: 0.577778
# Iteration 161, loss = 0.75735193
# Validation score: 0.611111
# Iteration 162, loss = 0.71816402
# Validation score: 0.600000
# Iteration 163, loss = 0.64120691
# Validation score: 0.577778
# Iteration 164, loss = 0.68467714
# Validation score: 0.622222
# Iteration 165, loss = 0.66165394
# Validation score: 0.566667
# Iteration 166, loss = 1.48438383
# Validation score: 0.555556
# Iteration 167, loss = 0.88824005
# Validation score: 0.577778
# Iteration 168, loss = 1.04213744
# Validation score: 0.566667
# Iteration 169, loss = 1.65145583
# Validation score: 0.622222
# Iteration 170, loss = 0.74971117
# Validation score: 0.555556
# Iteration 171, loss = 1.18037086
# Validation score: 0.411111
# Iteration 172, loss = 3.51301644
# Validation score: 0.566667
# Iteration 173, loss = 3.53122723
# Validation score: 0.566667
# Iteration 174, loss = 1.54218168
# Validation score: 0.400000
# Iteration 175, loss = 1.84098092
# Validation score: 0.588889
# Iteration 176, loss = 2.24069522
# Validation score: 0.588889
# Iteration 177, loss = 1.15339992
# Validation score: 0.488889
# Iteration 178, loss = 1.32163646
# Validation score: 0.566667
# Iteration 179, loss = 1.52774444
# Validation score: 0.433333
# Iteration 180, loss = 2.12114448
# Validation score: 0.555556
# Iteration 181, loss = 2.36907549
# Validation score: 0.611111
# Iteration 182, loss = 1.41420435
# Validation score: 0.588889
# Iteration 183, loss = 1.23585166
# Validation score: 0.500000
# Iteration 184, loss = 1.82246715
# Validation score: 0.566667
# Iteration 185, loss = 2.48194291
# Validation score: 0.566667
# Iteration 186, loss = 1.32222501
# Validation score: 0.400000
# Iteration 187, loss = 1.70075950
# Validation score: 0.555556
# Iteration 188, loss = 2.61234693
# Validation score: 0.577778
# Iteration 189, loss = 1.05823581
# Validation score: 0.400000
# Iteration 190, loss = 1.26072512
# Validation score: 0.566667
# Iteration 191, loss = 1.39812512
# Validation score: 0.411111
# Iteration 192, loss = 1.20750952
# Validation score: 0.566667
# Iteration 193, loss = 1.17073433
# Validation score: 0.533333
# Iteration 194, loss = 0.72084222
# Validation score: 0.566667
# Iteration 195, loss = 0.76141911
# Validation score: 0.555556
# Iteration 196, loss = 0.78654088
# Validation score: 0.577778
# Iteration 197, loss = 0.73398771
# Validation score: 0.600000
# Iteration 198, loss = 0.65019837
# Validation score: 0.611111
# Iteration 199, loss = 0.62581782
# Validation score: 0.477778
# Iteration 200, loss = 0.89142445
# Validation score: 0.566667
# MLPClassifier(early_stopping=True, hidden_layer_sizes=(2048,),
#               n_iter_no_change=100, random_state=100, verbose=True,
#               warm_start=True)

# %%
predictions = mlp.predict(xTest)
output = pd.DataFrame({'PassengerId': xTest.PassengerId, 'Survived': predictions})
output.to_csv('submissionDataCkeanCNN.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %% [markdown]
# ## Adding feature treatment

# %%
trainOriginalData = pd.read_csv('/kaggle/input/titanic/train.csv')
testOriginalData = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
trainOriginalData['Sex'] = pd.get_dummies(trainOriginalData['Sex'], dtype=int)["male"]
testOriginalData['Sex'] = pd.get_dummies(testOriginalData['Sex'], dtype=int)["male"]

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas    1  27.0      0
# 887                       Graham, Miss. Margaret Edith    0  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    0   NaN      1
# 889                              Behr, Mr. Karl Howell    1  26.0      0
# 890                                Dooley, Mr. Patrick    1  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
trainOriginalData["Age"] = trainOriginalData["Age"]/trainOriginalData["Age"].max()
trainOriginalData['Age'] = trainOriginalData['Age'].fillna(trainOriginalData['Age'].mean())

testOriginalData["Age"] = testOriginalData["Age"]/testOriginalData["Age"].max()
testOriginalData['Age'] = testOriginalData['Age'].fillna(testOriginalData['Age'].mean())

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  0.275000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.475000      1
# 2                               Heikkinen, Miss. Laina    0  0.325000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.437500      1
# 4                             Allen, Mr. William Henry    1  0.437500      0
# ..                                                 ...  ...       ...    ...
# 886                              Montvila, Rev. Juozas    1  0.337500      0
# 887                       Graham, Miss. Margaret Edith    0  0.237500      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  0.371239      1
# 889                              Behr, Mr. Karl Howell    1  0.325000      0
# 890                                Dooley, Mr. Patrick    1  0.400000      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
trainOriginalData = trainOriginalData.drop(["Ticket","Cabin","Name"], axis = 1)
testOriginalData = testOriginalData.drop(["Ticket","Cabin","Name"], axis = 1)

# %%
trainOriginalData
# Out:
#      PassengerId  Survived  Pclass  Sex       Age  SibSp  Parch     Fare  \
# 0              1         0       3    1  0.275000      1      0   7.2500
# 1              2         1       1    0  0.475000      1      0  71.2833
# 2              3         1       3    0  0.325000      0      0   7.9250
# 3              4         1       1    0  0.437500      1      0  53.1000
# 4              5         0       3    1  0.437500      0      0   8.0500
# ..           ...       ...     ...  ...       ...    ...    ...      ...
# 886          887         0       2    1  0.337500      0      0  13.0000
# 887          888         1       1    0  0.237500      0      0  30.0000
# 888          889         0       3    0  0.371239      1      2  23.4500
# 889          890         1       1    1  0.325000      0      0  30.0000
# 890          891         0       3    1  0.400000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
pd.get_dummies(trainOriginalData['Embarked'], dtype=int)
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
pd.concat([trainOriginalData, pd.get_dummies(trainOriginalData['Embarked'], dtype=int)], axis=1)
pd.concat([testOriginalData, pd.get_dummies(testOriginalData['Embarked'], dtype=int)], axis=1)
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare Embarked  C  \
# 0            892       3    1  0.453947      0      0    7.8292        Q  0
# 1            893       3    0  0.618421      1      0    7.0000        S  0
# 2            894       2    1  0.815789      0      0    9.6875        Q  0
# 3            895       3    1  0.355263      0      0    8.6625        S  0
# 4            896       3    0  0.289474      1      1   12.2875        S  0
# ..           ...     ...  ...       ...    ...    ...       ...      ... ..
# 413         1305       3    1  0.398324      0      0    8.0500        S  0
# 414         1306       1    0  0.513158      0      0  108.9000        C  1
# 415         1307       3    1  0.506579      0      0    7.2500        S  0
# 416         1308       3    1  0.398324      0      0    8.0500        S  0
# 417         1309       3    1  0.398324      1      1   22.3583        C  1
#
#      Q  S
# 0    1  0
# 1    0  1
# 2    1  0
# 3    0  1
# 4    0  1
# ..  .. ..
# 413  0  1
# 414  0  0
# 415  0  1
# 416  0  1
# 417  0  0
#
# [418 rows x 11 columns]

# %%
trainOriginalData = trainOriginalData.drop(["Embarked"], axis = 1)
testOriginalData = testOriginalData.drop(["Embarked"], axis = 1)

# %%
trainData = trainOriginalData
testData = testOriginalData

# %%
testData
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare
# 0            892       3    1  0.453947      0      0    7.8292
# 1            893       3    0  0.618421      1      0    7.0000
# 2            894       2    1  0.815789      0      0    9.6875
# 3            895       3    1  0.355263      0      0    8.6625
# 4            896       3    0  0.289474      1      1   12.2875
# ..           ...     ...  ...       ...    ...    ...       ...
# 413         1305       3    1  0.398324      0      0    8.0500
# 414         1306       1    0  0.513158      0      0  108.9000
# 415         1307       3    1  0.506579      0      0    7.2500
# 416         1308       3    1  0.398324      0      0    8.0500
# 417         1309       3    1  0.398324      1      1   22.3583
#
# [418 rows x 7 columns]

# %%
predictions = model.predict(xTest)

output = pd.DataFrame({'PassengerId': xTest.PassengerId, 'Survived': predictions})
output.to_csv('submissionTreatmentDataRF.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(num_hidden_units,),
    activation=activation,
    learning_rate_init=learning_rate_init,
    warm_start=True,
    verbose=True,
    random_state=SEED,
    early_stopping=True,
    n_iter_no_change=100, # large number of iterations to avoid early stopping message
)

# %%
mlp.fit(xTrain, yTrain)
predictions = mlp.predict(xTest)
output = pd.DataFrame({'PassengerId': xTest.PassengerId, 'Survived': predictions})
output.to_csv('submissionDataCkeanCNN.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Iteration 1, loss = 5.81026709
# Validation score: 0.611111
# Iteration 2, loss = 6.04625752
# Validation score: 0.388889
# Iteration 3, loss = 12.85304809
# Validation score: 0.388889
# Iteration 4, loss = 10.34043498
# Validation score: 0.622222
# Iteration 5, loss = 6.47621935
# Validation score: 0.600000
# Iteration 6, loss = 7.01355940
# Validation score: 0.566667
# Iteration 7, loss = 2.43751102
# Validation score: 0.422222
# Iteration 8, loss = 1.94751022
# Validation score: 0.555556
# Iteration 9, loss = 1.79168513
# Validation score: 0.566667
# Iteration 10, loss = 3.25066793
# Validation score: 0.566667
# Iteration 11, loss = 3.43532653
# Validation score: 0.377778
# Iteration 12, loss = 2.94885073
# Validation score: 0.600000
# Iteration 13, loss = 1.58540200
# Validation score: 0.433333
# Iteration 14, loss = 1.40266231
# Validation score: 0.577778
# Iteration 15, loss = 2.37525988
# Validation score: 0.588889
# Iteration 16, loss = 3.51408648
# Validation score: 0.588889
# Iteration 17, loss = 2.84054533
# Validation score: 0.433333
# Iteration 18, loss = 2.90830246
# Validation score: 0.577778
# Iteration 19, loss = 1.44910797
# Validation score: 0.600000
# Iteration 20, loss = 2.47933757
# Validation score: 0.611111
# Iteration 21, loss = 3.04037206
# Validation score: 0.400000
# Iteration 22, loss = 2.70987835
# Validation score: 0.555556
# Iteration 23, loss = 3.03953437
# Validation score: 0.566667
# Iteration 24, loss = 1.81916613
# Validation score: 0.411111
# Iteration 25, loss = 1.84947805
# Validation score: 0.588889
# Iteration 26, loss = 1.28632214
# Validation score: 0.611111
# Iteration 27, loss = 1.58297442
# Validation score: 0.577778
# Iteration 28, loss = 2.98330190
# Validation score: 0.544444
# Iteration 29, loss = 1.96250602
# Validation score: 0.555556
# Iteration 30, loss = 2.16041793
# Validation score: 0.488889
# Iteration 31, loss = 1.56661697
# Validation score: 0.600000
# Iteration 32, loss = 1.97586886
# Validation score: 0.533333
# Iteration 33, loss = 1.09572844
# Validation score: 0.577778
# Iteration 34, loss = 1.06979664
# Validation score: 0.611111
# Iteration 35, loss = 0.88486764
# Validation score: 0.466667
# Iteration 36, loss = 1.21577891
# Validation score: 0.577778
# Iteration 37, loss = 1.24589409
# Validation score: 0.422222
# Iteration 38, loss = 1.53702356
# Validation score: 0.577778
# Iteration 39, loss = 1.90788339
# Validation score: 0.400000
# Iteration 40, loss = 8.25061001
# Validation score: 0.400000
# Iteration 41, loss = 3.83332056
# Validation score: 0.611111
# Iteration 42, loss = 2.51243335
# Validation score: 0.411111
# Iteration 43, loss = 2.90121734
# Validation score: 0.600000
# Iteration 44, loss = 2.59424064
# Validation score: 0.600000
# Iteration 45, loss = 1.70187327
# Validation score: 0.544444
# Iteration 46, loss = 2.37840081
# Validation score: 0.566667
# Iteration 47, loss = 3.50945538
# Validation score: 0.500000
# Iteration 48, loss = 1.93787785
# Validation score: 0.388889
# Iteration 49, loss = 4.14427330
# Validation score: 0.644444
# Iteration 50, loss = 3.14547634
# Validation score: 0.600000
# Iteration 51, loss = 2.46763434
# Validation score: 0.466667
# Iteration 52, loss = 2.64413889
# Validation score: 0.633333
# Iteration 53, loss = 2.61154697
# Validation score: 0.577778
# Iteration 54, loss = 1.69759617
# Validation score: 0.455556
# Iteration 55, loss = 1.47685805
# Validation score: 0.577778
# Iteration 56, loss = 1.91596396
# Validation score: 0.577778
# Iteration 57, loss = 1.04313330
# Validation score: 0.577778
# Iteration 58, loss = 0.94157934
# Validation score: 0.566667
# Iteration 59, loss = 0.94058807
# Validation score: 0.622222
# Iteration 60, loss = 0.97782263
# Validation score: 0.488889
# Iteration 61, loss = 1.36827479
# Validation score: 0.566667
# Iteration 62, loss = 1.64374902
# Validation score: 0.555556
# Iteration 63, loss = 1.03858360
# Validation score: 0.577778
# Iteration 64, loss = 1.13605747
# Validation score: 0.588889
# Iteration 65, loss = 0.75703621
# Validation score: 0.466667
# Iteration 66, loss = 1.22958947
# Validation score: 0.566667
# Iteration 67, loss = 1.06449017
# Validation score: 0.488889
# Iteration 68, loss = 0.89921599
# Validation score: 0.555556
# Iteration 69, loss = 0.89749619
# Validation score: 0.588889
# Iteration 70, loss = 0.89510492
# Validation score: 0.600000
# Iteration 71, loss = 0.73067591
# Validation score: 0.555556
# Iteration 72, loss = 0.63372341
# Validation score: 0.622222
# Iteration 73, loss = 0.68807050
# Validation score: 0.555556
# Iteration 74, loss = 0.68023569
# Validation score: 0.555556
# Iteration 75, loss = 0.95315813
# Validation score: 0.622222
# Iteration 76, loss = 1.41040310
# Validation score: 0.600000
# Iteration 77, loss = 0.83250175
# Validation score: 0.600000
# Iteration 78, loss = 0.88565547
# Validation score: 0.455556
# Iteration 79, loss = 1.11665928
# Validation score: 0.644444
# Iteration 80, loss = 0.97771234
# Validation score: 0.600000
# Iteration 81, loss = 0.91739266
# Validation score: 0.611111
# Iteration 82, loss = 3.17589329
# Validation score: 0.622222
# Iteration 83, loss = 2.52596391
# Validation score: 0.577778
# Iteration 84, loss = 3.38198904
# Validation score: 0.655556
# Iteration 85, loss = 0.97721396
# Validation score: 0.600000
# Iteration 86, loss = 1.13584181
# Validation score: 0.577778
# Iteration 87, loss = 0.96194490
# Validation score: 0.611111
# Iteration 88, loss = 0.95233373
# Validation score: 0.488889
# Iteration 89, loss = 1.10993722
# Validation score: 0.655556
# Iteration 90, loss = 0.80844602
# Validation score: 0.600000
# Iteration 91, loss = 2.09465220
# Validation score: 0.566667
# Iteration 92, loss = 1.11035553
# Validation score: 0.566667
# Iteration 93, loss = 2.46974700
# Validation score: 0.566667
# Iteration 94, loss = 1.57748875
# Validation score: 0.555556
# Iteration 95, loss = 0.87607089
# Validation score: 0.511111
# Iteration 96, loss = 0.98580272
# Validation score: 0.544444
# Iteration 97, loss = 1.04507055
# Validation score: 0.400000
# Iteration 98, loss = 1.35080181
# Validation score: 0.611111
# Iteration 99, loss = 1.35275983
# Validation score: 0.388889
# Iteration 100, loss = 3.72080367
# Validation score: 0.611111
# Iteration 101, loss = 3.67813262
# Validation score: 0.622222
# Iteration 102, loss = 1.69033828
# Validation score: 0.455556
# Iteration 103, loss = 1.50455619
# Validation score: 0.600000
# Iteration 104, loss = 1.56161170
# Validation score: 0.544444
# Iteration 105, loss = 1.08405747
# Validation score: 0.588889
# Iteration 106, loss = 1.14800510
# Validation score: 0.611111
# Iteration 107, loss = 1.31263093
# Validation score: 0.488889
# Iteration 108, loss = 1.01672623
# Validation score: 0.555556
# Iteration 109, loss = 1.29570873
# Validation score: 0.411111
# Iteration 110, loss = 1.47429207
# Validation score: 0.588889
# Iteration 111, loss = 2.45461552
# Validation score: 0.511111
# Iteration 112, loss = 1.21653747
# Validation score: 0.600000
# Iteration 113, loss = 1.57538385
# Validation score: 0.577778
# Iteration 114, loss = 0.97252665
# Validation score: 0.611111
# Iteration 115, loss = 0.98172078
# Validation score: 0.588889
# Iteration 116, loss = 0.84049595
# Validation score: 0.600000
# Iteration 117, loss = 0.76171974
# Validation score: 0.555556
# Iteration 118, loss = 2.00184644
# Validation score: 0.611111
# Iteration 119, loss = 1.12753380
# Validation score: 0.633333
# Iteration 120, loss = 1.09586375
# Validation score: 0.555556
# Iteration 121, loss = 0.77158757
# Validation score: 0.588889
# Iteration 122, loss = 0.88612219
# Validation score: 0.588889
# Iteration 123, loss = 0.75756278
# Validation score: 0.622222
# Iteration 124, loss = 0.84442678
# Validation score: 0.477778
# Iteration 125, loss = 0.91071835
# Validation score: 0.566667
# Iteration 126, loss = 0.92972875
# Validation score: 0.444444
# Iteration 127, loss = 0.96451809
# Validation score: 0.555556
# Iteration 128, loss = 0.99147963
# Validation score: 0.422222
# Iteration 129, loss = 1.14771190
# Validation score: 0.577778
# Iteration 130, loss = 0.98786957
# Validation score: 0.411111
# Iteration 131, loss = 1.11757611
# Validation score: 0.566667
# Iteration 132, loss = 1.12425122
# Validation score: 0.611111
# Iteration 133, loss = 0.96995794
# Validation score: 0.644444
# Iteration 134, loss = 0.79183685
# Validation score: 0.644444
# Iteration 135, loss = 0.84985469
# Validation score: 0.488889
# Iteration 136, loss = 1.19798552
# Validation score: 0.666667
# Iteration 137, loss = 0.94434509
# Validation score: 0.577778
# Iteration 138, loss = 0.97293947
# Validation score: 0.466667
# Iteration 139, loss = 0.95540642
# Validation score: 0.566667
# Iteration 140, loss = 0.94596315
# Validation score: 0.566667
# Iteration 141, loss = 3.59377570
# Validation score: 0.577778
# Iteration 142, loss = 2.22312192
# Validation score: 0.488889
# Iteration 143, loss = 1.47563614
# Validation score: 0.555556
# Iteration 144, loss = 1.33455870
# Validation score: 0.533333
# Iteration 145, loss = 1.03243444
# Validation score: 0.488889
# Iteration 146, loss = 0.94419061
# Validation score: 0.555556
# Iteration 147, loss = 0.97238639
# Validation score: 0.566667
# Iteration 148, loss = 0.74027276
# Validation score: 0.633333
# Iteration 149, loss = 0.77831123
# Validation score: 0.588889
# Iteration 150, loss = 4.22321148
# Validation score: 0.577778
# Iteration 151, loss = 3.25023743
# Validation score: 0.400000
# Iteration 152, loss = 1.94954062
# Validation score: 0.566667
# Iteration 153, loss = 2.36813914
# Validation score: 0.566667
# Iteration 154, loss = 3.79373229
# Validation score: 0.522222
# Iteration 155, loss = 1.49267631
# Validation score: 0.577778
# Iteration 156, loss = 1.38462159
# Validation score: 0.444444
# Iteration 157, loss = 1.59927620
# Validation score: 0.600000
# Iteration 158, loss = 1.48855698
# Validation score: 0.466667
# Iteration 159, loss = 0.89360250
# Validation score: 0.611111
# Iteration 160, loss = 0.86847812
# Validation score: 0.577778
# Iteration 161, loss = 0.75735193
# Validation score: 0.611111
# Iteration 162, loss = 0.71816402
# Validation score: 0.600000
# Iteration 163, loss = 0.64120691
# Validation score: 0.577778
# Iteration 164, loss = 0.68467714
# Validation score: 0.622222
# Iteration 165, loss = 0.66165394
# Validation score: 0.566667
# Iteration 166, loss = 1.48438383
# Validation score: 0.555556
# Iteration 167, loss = 0.88824005
# Validation score: 0.577778
# Iteration 168, loss = 1.04213744
# Validation score: 0.566667
# Iteration 169, loss = 1.65145583
# Validation score: 0.622222
# Iteration 170, loss = 0.74971117
# Validation score: 0.555556
# Iteration 171, loss = 1.18037086
# Validation score: 0.411111
# Iteration 172, loss = 3.51301644
# Validation score: 0.566667
# Iteration 173, loss = 3.53122723
# Validation score: 0.566667
# Iteration 174, loss = 1.54218168
# Validation score: 0.400000
# Iteration 175, loss = 1.84098092
# Validation score: 0.588889
# Iteration 176, loss = 2.24069522
# Validation score: 0.588889
# Iteration 177, loss = 1.15339992
# Validation score: 0.488889
# Iteration 178, loss = 1.32163646
# Validation score: 0.566667
# Iteration 179, loss = 1.52774444
# Validation score: 0.433333
# Iteration 180, loss = 2.12114448
# Validation score: 0.555556
# Iteration 181, loss = 2.36907549
# Validation score: 0.611111
# Iteration 182, loss = 1.41420435
# Validation score: 0.588889
# Iteration 183, loss = 1.23585166
# Validation score: 0.500000
# Iteration 184, loss = 1.82246715
# Validation score: 0.566667
# Iteration 185, loss = 2.48194291
# Validation score: 0.566667
# Iteration 186, loss = 1.32222501
# Validation score: 0.400000
# Iteration 187, loss = 1.70075950
# Validation score: 0.555556
# Iteration 188, loss = 2.61234693
# Validation score: 0.577778
# Iteration 189, loss = 1.05823581
# Validation score: 0.400000
# Iteration 190, loss = 1.26072512
# Validation score: 0.566667
# Iteration 191, loss = 1.39812512
# Validation score: 0.411111
# Iteration 192, loss = 1.20750952
# Validation score: 0.566667
# Iteration 193, loss = 1.17073433
# Validation score: 0.533333
# Iteration 194, loss = 0.72084222
# Validation score: 0.566667
# Iteration 195, loss = 0.76141911
# Validation score: 0.555556
# Iteration 196, loss = 0.78654088
# Validation score: 0.577778
# Iteration 197, loss = 0.73398771
# Validation score: 0.600000
# Iteration 198, loss = 0.65019837
# Validation score: 0.611111
# Iteration 199, loss = 0.62581782
# Validation score: 0.477778
# Iteration 200, loss = 0.89142445
# Validation score: 0.566667
# Your submission was successfully saved!
